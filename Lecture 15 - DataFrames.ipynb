# %%
import numpy as np

# %%
import pandas as pd

# %%
from pandas import Series,DataFrame

# %%
import webbrowser

# %%
website='http://en.wikipedia.org/wiki/NFL_win-loss_records'

# %%
webbrowser.open(website)
# Out:
# True

# %%
nf1_frame = pd.read_clipboard()

# %%
nf1_frame
# Out:
#    Rank                  Team     GP  Won   Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,384  769  577.0  38.0  0.569
# 1     2        Dallas Cowboys    930  526  398.0   6.0  0.569
# 2     3      Baltimore Ravens    400  225  174.0   1.0  0.564
# 3     4         Chicago Bears  1,418  777  599.0  42.0  0.563
# 4     5  New England Patriots    932  519    NaN   NaN    NaN
#
#    First NFL season   Division
# 0            1921.0  NFC North
# 1            1960.0   NFC East
# 2            1996.0  AFC North
# 3            1920.0  NFC North
# 4               NaN        NaN

# %%
nf1_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL season',
#        'Division'],
#       dtype='object')

# %%
nf1_frame['First NFL season']
# Out:
# 0    1921.0
# 1    1960.0
# 2    1996.0
# 3    1920.0
# 4       NaN
# Name: First NFL season, dtype: float64

# %%
DataFrame(nf1_frame,columns=['Team','Rank','Lost'])
# Out:
#                    Team  Rank   Lost
# 0     Green Bay Packers     1  577.0
# 1        Dallas Cowboys     2  398.0
# 2      Baltimore Ravens     3  174.0
# 3         Chicago Bears     4  599.0
# 4  New England Patriots     5    NaN

# %%
DataFrame(nf1_frame,columns=['Team','Rank','Lost','Stadium'])
# Out:
#                    Team  Rank   Lost  Stadium
# 0     Green Bay Packers     1  577.0      NaN
# 1        Dallas Cowboys     2  398.0      NaN
# 2      Baltimore Ravens     3  174.0      NaN
# 3         Chicago Bears     4  599.0      NaN
# 4  New England Patriots     5    NaN      NaN

# %%
nf1_frame
# Out:
#    Rank                  Team     GP  Won   Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,384  769  577.0  38.0  0.569
# 1     2        Dallas Cowboys    930  526  398.0   6.0  0.569
# 2     3      Baltimore Ravens    400  225  174.0   1.0  0.564
# 3     4         Chicago Bears  1,418  777  599.0  42.0  0.563
# 4     5  New England Patriots    932  519    NaN   NaN    NaN
#
#    First NFL season   Division
# 0            1921.0  NFC North
# 1            1960.0   NFC East
# 2            1996.0  AFC North
# 3            1920.0  NFC North
# 4               NaN        NaN

# %%
nf1_frame.head(3)
# Out:
#    Rank               Team     GP  Won   Lost  Tied   Pct.  First NFL season  \
# 0     1  Green Bay Packers  1,384  769  577.0  38.0  0.569            1921.0
# 1     2     Dallas Cowboys    930  526  398.0   6.0  0.569            1960.0
# 2     3   Baltimore Ravens    400  225  174.0   1.0  0.564            1996.0
#
#     Division
# 0  NFC North
# 1   NFC East
# 2  AFC North

# %%
nf1_frame.tail(3)
# Out:
#    Rank                  Team     GP  Won   Lost  Tied   Pct.  \
# 2     3      Baltimore Ravens    400  225  174.0   1.0  0.564
# 3     4         Chicago Bears  1,418  777  599.0  42.0  0.563
# 4     5  New England Patriots    932  519    NaN   NaN    NaN
#
#    First NFL season   Division
# 2            1996.0  AFC North
# 3            1920.0  NFC North
# 4               NaN        NaN

# %%
nf1_frame.index[3]
# Out:
# 3

# %%
nf1_frame['Stadium'] = "levi's Stadium"

# %%
nf1_frame
# Out:
#    Rank                  Team     GP  Won   Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,384  769  577.0  38.0  0.569
# 1     2        Dallas Cowboys    930  526  398.0   6.0  0.569
# 2     3      Baltimore Ravens    400  225  174.0   1.0  0.564
# 3     4         Chicago Bears  1,418  777  599.0  42.0  0.563
# 4     5  New England Patriots    932  519    NaN   NaN    NaN
#
#    First NFL season   Division         Stadium
# 0            1921.0  NFC North  levi's Stadium
# 1            1960.0   NFC East  levi's Stadium
# 2            1996.0  AFC North  levi's Stadium
# 3            1920.0  NFC North  levi's Stadium
# 4               NaN        NaN  levi's Stadium

# %%
nf1_frame['Stadium'] = np.arange(5)

# %%
nf1_frame
# Out:
#    Rank                  Team     GP  Won   Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,384  769  577.0  38.0  0.569
# 1     2        Dallas Cowboys    930  526  398.0   6.0  0.569
# 2     3      Baltimore Ravens    400  225  174.0   1.0  0.564
# 3     4         Chicago Bears  1,418  777  599.0  42.0  0.563
# 4     5  New England Patriots    932  519    NaN   NaN    NaN
#
#    First NFL season   Division  Stadium
# 0            1921.0  NFC North        0
# 1            1960.0   NFC East        1
# 2            1996.0  AFC North        2
# 3            1920.0  NFC North        3
# 4               NaN        NaN        4

# %%
stadiums = Series(["Levi's stadium","AT&T stadium"],index=[4,0])

# %%
stadiums
# Out:
# 4    Levi's stadium
# 0      AT&T stadium
# dtype: object

# %%
nf1_frame['Stadium'] = stadiums

# %%
nf1_frame
# Out:
#    Rank                  Team     GP  Won   Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,384  769  577.0  38.0  0.569
# 1     2        Dallas Cowboys    930  526  398.0   6.0  0.569
# 2     3      Baltimore Ravens    400  225  174.0   1.0  0.564
# 3     4         Chicago Bears  1,418  777  599.0  42.0  0.563
# 4     5  New England Patriots    932  519    NaN   NaN    NaN
#
#    First NFL season   Division         Stadium
# 0            1921.0  NFC North    AT&T stadium
# 1            1960.0   NFC East             NaN
# 2            1996.0  AFC North             NaN
# 3            1920.0  NFC North             NaN
# 4               NaN        NaN  Levi's stadium

# %%
del nf1_frame['Stadium']

# %%
nf1_frame
# Out:
#    Rank                  Team     GP  Won   Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,384  769  577.0  38.0  0.569
# 1     2        Dallas Cowboys    930  526  398.0   6.0  0.569
# 2     3      Baltimore Ravens    400  225  174.0   1.0  0.564
# 3     4         Chicago Bears  1,418  777  599.0  42.0  0.563
# 4     5  New England Patriots    932  519    NaN   NaN    NaN
#
#    First NFL season   Division
# 0            1921.0  NFC North
# 1            1960.0   NFC East
# 2            1996.0  AFC North
# 3            1920.0  NFC North
# 4               NaN        NaN

# %%
data = {'city':['sf','la','nyc'],'population':[30000,70000,50000]}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   city  population
# 0   sf       30000
# 1   la       70000
# 2  nyc       50000
